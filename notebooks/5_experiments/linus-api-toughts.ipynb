# %% [markdown]
# ### API plan

# %% [markdown]
# copy of lecture api code as a guidance

# %%
# !pip install fastapi
# Out:
# ...
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# ...
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached pydantic_core-2.41.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# ...
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# ...
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [fastapi]━━━ 6/7 [fastapi]tarlette]
# ...

# %%
# !pip install uvicorn
# Out:
# ...
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# ...
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [uvicorn]━━━ 1/2 [uvicorn]
# ...

# %%
from fastapi import FastAPI

app = FastAPI()

# Define a root `/` endpoint
@app.get('/')
def index():
    return {'ok': True}

# %%
url = 'http://localhost:8000/predict'

params = {
    'day_of_week': 0, # 0 for Sunday, 1 for Monday, ...
    'time': '14:00'
}

response = requests.get(url, params=params)
response.json() #=> {wait: 64}

# %% [markdown]
# start local server with !uvicorn name_of_py_file:app? (dunno if that works from within a notebook)

# %% [markdown]
# folder structure: backend-api/main.py and __init__.py,
# main.py with app

# %%
app.state.model = load_model()

# http://127.0.0.1:8000/predict?pickup_datetime=2014-07-06+19:18:00&pickup_longitude=-73.950655&pickup_latitude=40.783282&dropoff_longitude=-73.984365&dropoff_latitude=40.769802&passenger_count=2
@app.get("/predict")
def predict(
    audiofile?:mp3?
    demographic_data:txt, csv?
    ):
    """
    Make a categorical diagnosis prediction.
    idk how to input audiofiles
    """



    X_tabular = tabular_proc(demographic_data)
    X_audio = audio_proc(audiofile)
    #do prediction stuff with both: (does the audiofile process produce
    #the weezles and cackles as we had in the audio txt files?)
    #combine the findings? or combine the data stuff and then predict in one model?
    model = app.state.model
    assert model is not None

    X_processed = some combination of X_tab and X_audio
    y_pred = model.predict(X_processed)
    #y_pred will be a number for the diagnosis, so need to retranslate that here?

    return dict(diagnosis=str(y_pred))
