# %%
import numpy as np
import pandas as pd
import seaborn as sns
import librosa as lb
import soundfile as sf
from pathlib import Path
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report
from tensorflow.keras import layers, models, activations
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.utils.class_weight import compute_class_weight
from audiomentations import AddGaussianNoise, TimeStretch, Shift, Gain
import random

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from smart_stethoscope.interface import main
X_train, X_test, y_train, y_test, train_cycle_filenames, test_cycle_filenames = main.preprocessing()
# Out:
# ✅ Processed audio files already exist, skipping extraction
#
# Load data from cached CSV...
# /Users/miameyer/.pyenv/versions/3.10.6/envs/smart-stethoscope/lib/python3.10/site-packages/sklearn/pipeline.py:61: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(

# %%
train_cycle_filenames
# Out:
# array(['148_1b1_Al_sc_Meditron_0', '148_1b1_Al_sc_Meditron_1',
#        '148_1b1_Al_sc_Meditron_2', ..., '116_1b2_Pl_sc_Meditron_1',
#        '116_1b2_Pl_sc_Meditron_2', '116_1b2_Pl_sc_Meditron_3'],
#       shape=(5806,), dtype=object)

# %%
def get_audio_data(cycle_filenames):
  folder = Path('../preprocessed_data/padded_audio_breathing_cycles')
  audios = []
  for filename in cycle_filenames:
    filename = filename + ".wav"
    full_file_name = folder / filename
    audio, sr = lb.load(full_file_name, sr=None)
    audios.append(audio)
  audio_array = np.stack(audios).astype(np.float32)
  return audio_array

# %%
audio_train_array = get_audio_data(train_cycle_filenames)
audio_test_array = get_audio_data(test_cycle_filenames)

# %% [markdown]
# ### Data Augmentation

# %%
class RespiratoryCycleAugment:
    def __init__(self, sample_rate=4000):
        self.sample_rate = sample_rate

        # VERY conservative settings
        self.noise = AddGaussianNoise(
            min_amplitude=0.0005,
            max_amplitude=0.005,
            p=0.4
        )

        self.time_stretch = TimeStretch(
            min_rate=0.95,
            max_rate=1.05,
            leave_length_unchanged=True,
            p=0.3
        )

        self.shift = Shift(
            min_shift=-0.05,
            max_shift=0.05,
            p=0.3
        )

        self.gain = Gain(
            min_gain_db=-3,
            max_gain_db=3,
            p=0.3
        )

    def __call__(self, x):
        x = self.noise(x, sample_rate=self.sample_rate)
        x = self.time_stretch(x, sample_rate=self.sample_rate)
        x = self.shift(x, sample_rate=self.sample_rate)
        x = self.gain(x, sample_rate=self.sample_rate)
        return x

# %%
def augment_batch(audio_array, labels, augmenter):
    X_train_new = []
    y_train_new = []

    for x, y in zip(audio_array, labels):
        X_train_new.append(x)
        y_train_new.append(y)

        if y == 0: #healthy
            if random.random() < 0.2:
                x = augmenter(x)
                X_train_new.append(x)
                y_train_new.append(y)
        elif y == 1: #COPD
            if random.random() < 0.05:
                x = augmenter(x)
                X_train_new.append(x)
                y_train_new.append(y)
        elif y in [2, 4]:
            if random.random() < 0.3:
                x = augmenter(x)
                X_train_new.append(x)
                y_train_new.append(y)
        elif y ==3:
            if random.random() < 0.5:
                x = augmenter(x)
                X_train_new.append(x)
                y_train_new.append(y)
        elif y ==5:
            if random.random() < 0.4:
                x = augmenter(x)
                X_train_new.append(x)
                y_train_new.append(y)

    return np.stack(X_train_new).astype(np.float32), np.stack(y_train_new)

# %% [markdown]
# Do not use this, to aggressive:

# %%
from collections import defaultdict

def augment_to_target(audio_array, labels, augmenter, target_size=1000):
    X_new = []
    y_new = []

    # group indices by class
    class_indices = defaultdict(list)
    for i, y in enumerate(labels):
        class_indices[y].append(i)

    for cls, indices in class_indices.items():
        current_count = len(indices)

        # always keep originals
        for i in indices:
            X_new.append(audio_array[i])
            y_new.append(cls)

        # compute how many more we need
        if current_count < target_size:
            needed = target_size - current_count

            for _ in range(needed):
                i = random.choice(indices)
                x = audio_array[i]

                x_aug = augmenter(x)
                X_new.append(x_aug)
                y_new.append(cls)

    return np.stack(X_new).astype(np.float32), np.array(y_new)

# %%
augmenter = RespiratoryCycleAugment(sample_rate=22050)

minority_classes = [0, 2, 3, 4, 5]

X_train_aug, y_train_aug = augment_batch(
    audio_array=audio_train_array,
    labels=y_train,
    augmenter=augmenter,
)

# %%
def downsample_copd(X, y, copd_label, keep_ratio=0.3):

    # indices
    copd_indices = np.where(y == copd_label)[0]
    other_indices = np.where(y != copd_label)[0]

    # randomly select subset of COPD
    n_keep = int(len(copd_indices) * keep_ratio)
    selected_copd = np.random.choice(copd_indices, n_keep, replace=False)

    # combine
    selected_indices = np.concatenate([selected_copd, other_indices])
    np.random.shuffle(selected_indices)

    return X[selected_indices], y[selected_indices]

# %%
X_train_ds, y_train_ds = downsample_copd(
    X_train_aug,
    y_train_aug,
    copd_label=1,
    keep_ratio=0.3
)

# %%
y_train.shape
# Out:
# (5806,)

# %%
y_train_ds.shape
# Out:
# (2758,)

# %%
plt.hist(y_train_ds);

# %%
from joblib import Parallel, delayed

def process_audio(audio):
    mel_spec = lb.feature.melspectrogram(
        y=audio,
        sr=22050,
        n_mels=128
    )
    return lb.power_to_db(mel_spec, ref=np.max)

def get_mels(audio_array):
    mels = Parallel(n_jobs=-1)(
        delayed(process_audio)(audio) for audio in audio_array
    )

    return np.stack(mels)[..., np.newaxis]

# %%
X_train_img = get_mels(X_train_aug)
X_test_img = get_mels(audio_test_array)

# %% [markdown]
# ### Encode Calss Labels

# %%
y_train = pd.Series(y_train_aug)

# %%
# Check shape of data
print("y_train shape before encoding:", y_train.shape)
print("y_test shape before encoding:", y_test.shape)

# Check class labels
print("Unique train labels:", sorted(y_train.unique()))
print("Unique test labels:", sorted(y_test.unique()))

# Calculate number of classes
num_classes = len(np.unique(y_train))
print("Number of classes:", num_classes)
# Out:
# y_train shape before encoding: (6321,)
# y_test shape before encoding: (1054,)
# Unique train labels: [np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5)]
# Unique test labels: [np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5)]
# Number of classes: 6

# %%
# Convert integer labels to one-hot encoded arrays
# Example: class 2 becomes [0, 0, 1, 0, 0, 0]
y_train_cat = to_categorical(y_train, num_classes=num_classes)
y_test_cat = to_categorical(y_test, num_classes=num_classes)

# Check the new shapes
print("y_train_cat shape:", y_train_cat.shape)
print("y_test_cat shape:", y_test_cat.shape)

# Look at one example
print("First raw label:", y_train.iloc[0])
print("First one-hot label:", y_train_cat[0])
# Out:
# y_train_cat shape: (6321, 6)
# y_test_cat shape: (1054, 6)
# First raw label: 2
# First one-hot label: [0. 0. 1. 0. 0. 0.]

# %% [markdown]
# ### Build CNN

# %%
input_shape = X_train_img.shape[1:]
input_shape
# Out:
# (128, 259, 1)

# %%
# Convert one-hot back to integer labels
y_train_int = np.argmax(y_train_cat, axis=1)

# Compute class weights
class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(y_train_int),
    y=y_train_int
)

class_weights_dict = dict(enumerate(class_weights))

# %% [markdown]
# ### Test Model from Notebook

# %%
mSpec_input=layers.Input(shape=input_shape,name="mSpecInput")
x=layers.Conv2D(32,5,strides=(2,3),padding='same')(mSpec_input)
x=layers.BatchNormalization()(x)
x=layers.Activation(activations.relu)(x)
x=layers.MaxPooling2D(pool_size=2,padding='valid')(x)

x=layers.Conv2D(64,3,strides=(2,2),padding='same')(x)
x=layers.BatchNormalization()(x)
x=layers.Activation(activations.relu)(x)
x=layers.MaxPooling2D(pool_size=2,padding='valid')(x)

x=layers.Conv2D(96,2,padding='same')(x)
x=layers.BatchNormalization()(x)
x=layers.Activation(activations.relu)(x)
x=layers.MaxPooling2D(pool_size=2,padding='valid')(x)

x=layers.Conv2D(128,2,padding='same')(x)
x=layers.BatchNormalization()(x)
x=layers.Activation(activations.relu)(x)
x=layers.GlobalMaxPooling2D()(x)

x = layers.Dense(32, activations.relu)(x)
x = layers.Dropout(0.3)(x)
mSpec_output = layers.Dense(num_classes, activations.softmax)(x)

mSpec_model=tf.keras.Model(mSpec_input, mSpec_output, name="mSpecModel")

# %%
from tensorflow.keras.optimizers import Adam
optimizer = Adam(learning_rate=0.001)
mSpec_model.compile(
    optimizer=optimizer,
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
early_stopping = EarlyStopping(
    monitor="val_loss",
    patience=20, # instead of 3
    restore_best_weights=True
)
my_callbacks = [
    early_stopping,
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                              patience=3, min_lr=0.00001,mode='min')
]

history = mSpec_model.fit(
    X_train_img,
    y_train_cat,
    validation_split=0.2,
    epochs=200,
    batch_size=32,
    class_weight=class_weights_dict,
    callbacks=[my_callbacks],
    verbose=1
)

test_loss, test_accuracy = mSpec_model.evaluate(X_test_img, y_test_cat, verbose=1)

print("Test loss:", test_loss)
print("Test accuracy:", test_accuracy)
# Out:
# Epoch 1/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.2589 - loss: 1.8351 - val_accuracy: 0.0609 - val_loss: 1.9030 - learning_rate: 0.0010
# Epoch 2/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.3172 - loss: 1.5173 - val_accuracy: 0.0206 - val_loss: 2.8915 - learning_rate: 0.0010
# Epoch 3/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.3461 - loss: 1.3544 - val_accuracy: 0.5755 - val_loss: 1.2037 - learning_rate: 0.0010
# Epoch 4/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.4062 - loss: 1.2037 - val_accuracy: 0.1494 - val_loss: 2.7216 - learning_rate: 0.0010
# Epoch 5/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.4866 - loss: 1.0911 - val_accuracy: 0.0640 - val_loss: 1.8647 - learning_rate: 0.0010
# Epoch 6/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.5708 - loss: 0.9686 - val_accuracy: 0.4530 - val_loss: 1.6140 - learning_rate: 0.0010
# Epoch 7/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.6309 - loss: 0.8256 - val_accuracy: 0.7383 - val_loss: 0.6922 - learning_rate: 1.0000e-04
# Epoch 8/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.6695 - loss: 0.7528 - val_accuracy: 0.7123 - val_loss: 0.7951 - learning_rate: 1.0000e-04
# Epoch 9/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.6727 - loss: 0.7427 - val_accuracy: 0.7304 - val_loss: 0.7108 - learning_rate: 1.0000e-04
# Epoch 10/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.6930 - loss: 0.6906 - val_accuracy: 0.7138 - val_loss: 0.6914 - learning_rate: 1.0000e-04
# Epoch 11/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7110 - loss: 0.6514 - val_accuracy: 0.7486 - val_loss: 0.6382 - learning_rate: 1.0000e-04
# Epoch 12/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.7340 - loss: 0.6229 - val_accuracy: 0.7470 - val_loss: 0.6843 - learning_rate: 1.0000e-04
# Epoch 13/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.7492 - loss: 0.5791 - val_accuracy: 0.7644 - val_loss: 0.6249 - learning_rate: 1.0000e-04
# Epoch 14/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.7549 - loss: 0.5641 - val_accuracy: 0.7486 - val_loss: 0.6696 - learning_rate: 1.0000e-04
# Epoch 15/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.7727 - loss: 0.5309 - val_accuracy: 0.7937 - val_loss: 0.5712 - learning_rate: 1.0000e-04
# Epoch 16/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.7757 - loss: 0.5035 - val_accuracy: 0.8277 - val_loss: 0.4596 - learning_rate: 1.0000e-04
# Epoch 17/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.7939 - loss: 0.4905 - val_accuracy: 0.7407 - val_loss: 0.7513 - learning_rate: 1.0000e-04
# Epoch 18/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8131 - loss: 0.4370 - val_accuracy: 0.8063 - val_loss: 0.5335 - learning_rate: 1.0000e-04
# Epoch 19/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8115 - loss: 0.4124 - val_accuracy: 0.7684 - val_loss: 0.6387 - learning_rate: 1.0000e-04
# Epoch 20/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8165 - loss: 0.4072 - val_accuracy: 0.8285 - val_loss: 0.4694 - learning_rate: 1.0000e-05
# Epoch 21/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8163 - loss: 0.3908 - val_accuracy: 0.8213 - val_loss: 0.4750 - learning_rate: 1.0000e-05
# Epoch 22/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8188 - loss: 0.4029 - val_accuracy: 0.8166 - val_loss: 0.5010 - learning_rate: 1.0000e-05
# Epoch 23/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8258 - loss: 0.3832 - val_accuracy: 0.8300 - val_loss: 0.4694 - learning_rate: 1.0000e-05
# Epoch 24/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8271 - loss: 0.3801 - val_accuracy: 0.8292 - val_loss: 0.4791 - learning_rate: 1.0000e-05
# Epoch 25/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8265 - loss: 0.3862 - val_accuracy: 0.8206 - val_loss: 0.4926 - learning_rate: 1.0000e-05
# Epoch 26/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8327 - loss: 0.3875 - val_accuracy: 0.8182 - val_loss: 0.5013 - learning_rate: 1.0000e-05
# Epoch 27/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8348 - loss: 0.3740 - val_accuracy: 0.8221 - val_loss: 0.4837 - learning_rate: 1.0000e-05
# Epoch 28/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8301 - loss: 0.3680 - val_accuracy: 0.8292 - val_loss: 0.4730 - learning_rate: 1.0000e-05
# Epoch 29/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8352 - loss: 0.3655 - val_accuracy: 0.8126 - val_loss: 0.5174 - learning_rate: 1.0000e-05
# Epoch 30/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8311 - loss: 0.3595 - val_accuracy: 0.8277 - val_loss: 0.4729 - learning_rate: 1.0000e-05
# Epoch 31/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8360 - loss: 0.3652 - val_accuracy: 0.8316 - val_loss: 0.4640 - learning_rate: 1.0000e-05
# Epoch 32/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8384 - loss: 0.3552 - val_accuracy: 0.8364 - val_loss: 0.4598 - learning_rate: 1.0000e-05
# Epoch 33/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8376 - loss: 0.3521 - val_accuracy: 0.8332 - val_loss: 0.4560 - learning_rate: 1.0000e-05
# Epoch 34/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8432 - loss: 0.3601 - val_accuracy: 0.8213 - val_loss: 0.5062 - learning_rate: 1.0000e-05
# Epoch 35/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8331 - loss: 0.3496 - val_accuracy: 0.8237 - val_loss: 0.4869 - learning_rate: 1.0000e-05
# Epoch 36/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8354 - loss: 0.3421 - val_accuracy: 0.8206 - val_loss: 0.4820 - learning_rate: 1.0000e-05
# Epoch 37/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8410 - loss: 0.3452 - val_accuracy: 0.8277 - val_loss: 0.4877 - learning_rate: 1.0000e-05
# Epoch 38/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8410 - loss: 0.3399 - val_accuracy: 0.8300 - val_loss: 0.4790 - learning_rate: 1.0000e-05
# Epoch 39/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8473 - loss: 0.3466 - val_accuracy: 0.8490 - val_loss: 0.4264 - learning_rate: 1.0000e-05
# Epoch 40/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8445 - loss: 0.3318 - val_accuracy: 0.8340 - val_loss: 0.4671 - learning_rate: 1.0000e-05
# Epoch 41/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8436 - loss: 0.3386 - val_accuracy: 0.8213 - val_loss: 0.4986 - learning_rate: 1.0000e-05
# Epoch 42/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8511 - loss: 0.3152 - val_accuracy: 0.8356 - val_loss: 0.4615 - learning_rate: 1.0000e-05
# Epoch 43/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8477 - loss: 0.3285 - val_accuracy: 0.8348 - val_loss: 0.4626 - learning_rate: 1.0000e-05
# Epoch 44/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8477 - loss: 0.3444 - val_accuracy: 0.8379 - val_loss: 0.4401 - learning_rate: 1.0000e-05
# Epoch 45/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8422 - loss: 0.3355 - val_accuracy: 0.8443 - val_loss: 0.4453 - learning_rate: 1.0000e-05
# Epoch 46/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8536 - loss: 0.3207 - val_accuracy: 0.8277 - val_loss: 0.4818 - learning_rate: 1.0000e-05
# Epoch 47/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8546 - loss: 0.3089 - val_accuracy: 0.8332 - val_loss: 0.4714 - learning_rate: 1.0000e-05
# Epoch 48/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8550 - loss: 0.3081 - val_accuracy: 0.8316 - val_loss: 0.4786 - learning_rate: 1.0000e-05
# Epoch 49/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8447 - loss: 0.3257 - val_accuracy: 0.8348 - val_loss: 0.4592 - learning_rate: 1.0000e-05
# Epoch 50/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8546 - loss: 0.3153 - val_accuracy: 0.8285 - val_loss: 0.4746 - learning_rate: 1.0000e-05
# Epoch 51/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8509 - loss: 0.3195 - val_accuracy: 0.8316 - val_loss: 0.4761 - learning_rate: 1.0000e-05
# Epoch 52/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8548 - loss: 0.3174 - val_accuracy: 0.8372 - val_loss: 0.4489 - learning_rate: 1.0000e-05
# Epoch 53/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8530 - loss: 0.2904 - val_accuracy: 0.8451 - val_loss: 0.4374 - learning_rate: 1.0000e-05
# Epoch 54/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8479 - loss: 0.3094 - val_accuracy: 0.8364 - val_loss: 0.4643 - learning_rate: 1.0000e-05
# Epoch 55/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8560 - loss: 0.2922 - val_accuracy: 0.8403 - val_loss: 0.4516 - learning_rate: 1.0000e-05
# Epoch 56/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8566 - loss: 0.3087 - val_accuracy: 0.8245 - val_loss: 0.4948 - learning_rate: 1.0000e-05
# Epoch 57/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8562 - loss: 0.2890 - val_accuracy: 0.8403 - val_loss: 0.4535 - learning_rate: 1.0000e-05
# Epoch 58/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8614 - loss: 0.3010 - val_accuracy: 0.8490 - val_loss: 0.4240 - learning_rate: 1.0000e-05
# Epoch 59/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8590 - loss: 0.2977 - val_accuracy: 0.8277 - val_loss: 0.4861 - learning_rate: 1.0000e-05
# Epoch 60/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8540 - loss: 0.2846 - val_accuracy: 0.8530 - val_loss: 0.4193 - learning_rate: 1.0000e-05
# Epoch 61/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8586 - loss: 0.3029 - val_accuracy: 0.8395 - val_loss: 0.4473 - learning_rate: 1.0000e-05
# Epoch 62/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8665 - loss: 0.2671 - val_accuracy: 0.8443 - val_loss: 0.4418 - learning_rate: 1.0000e-05
# Epoch 63/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8562 - loss: 0.2989 - val_accuracy: 0.8356 - val_loss: 0.4571 - learning_rate: 1.0000e-05
# Epoch 64/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8657 - loss: 0.2760 - val_accuracy: 0.8427 - val_loss: 0.4447 - learning_rate: 1.0000e-05
# Epoch 65/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8679 - loss: 0.2719 - val_accuracy: 0.8506 - val_loss: 0.4233 - learning_rate: 1.0000e-05
# Epoch 66/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8645 - loss: 0.2928 - val_accuracy: 0.8340 - val_loss: 0.4669 - learning_rate: 1.0000e-05
# Epoch 67/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8562 - loss: 0.2827 - val_accuracy: 0.8403 - val_loss: 0.4519 - learning_rate: 1.0000e-05
# Epoch 68/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8683 - loss: 0.2666 - val_accuracy: 0.8443 - val_loss: 0.4315 - learning_rate: 1.0000e-05
# Epoch 69/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8637 - loss: 0.2879 - val_accuracy: 0.8403 - val_loss: 0.4589 - learning_rate: 1.0000e-05
# Epoch 70/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8635 - loss: 0.2607 - val_accuracy: 0.8545 - val_loss: 0.4209 - learning_rate: 1.0000e-05
# Epoch 71/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8732 - loss: 0.2668 - val_accuracy: 0.8387 - val_loss: 0.4509 - learning_rate: 1.0000e-05
# Epoch 72/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8703 - loss: 0.2667 - val_accuracy: 0.8482 - val_loss: 0.4300 - learning_rate: 1.0000e-05
# Epoch 73/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8655 - loss: 0.2696 - val_accuracy: 0.8403 - val_loss: 0.4480 - learning_rate: 1.0000e-05
# Epoch 74/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8675 - loss: 0.2627 - val_accuracy: 0.8411 - val_loss: 0.4395 - learning_rate: 1.0000e-05
# Epoch 75/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8647 - loss: 0.2666 - val_accuracy: 0.8506 - val_loss: 0.4243 - learning_rate: 1.0000e-05
# Epoch 76/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8681 - loss: 0.2633 - val_accuracy: 0.8427 - val_loss: 0.4394 - learning_rate: 1.0000e-05
# Epoch 77/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8691 - loss: 0.2726 - val_accuracy: 0.8379 - val_loss: 0.4624 - learning_rate: 1.0000e-05
# Epoch 78/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8655 - loss: 0.2562 - val_accuracy: 0.8387 - val_loss: 0.4375 - learning_rate: 1.0000e-05
# Epoch 79/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8665 - loss: 0.2654 - val_accuracy: 0.8387 - val_loss: 0.4480 - learning_rate: 1.0000e-05
# Epoch 80/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8705 - loss: 0.2538 - val_accuracy: 0.8625 - val_loss: 0.3976 - learning_rate: 1.0000e-05
# Epoch 81/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8663 - loss: 0.2564 - val_accuracy: 0.8292 - val_loss: 0.4532 - learning_rate: 1.0000e-05
# Epoch 82/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8693 - loss: 0.2598 - val_accuracy: 0.8640 - val_loss: 0.3875 - learning_rate: 1.0000e-05
# Epoch 83/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8756 - loss: 0.2434 - val_accuracy: 0.8585 - val_loss: 0.4124 - learning_rate: 1.0000e-05
# Epoch 84/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8740 - loss: 0.2532 - val_accuracy: 0.8300 - val_loss: 0.4776 - learning_rate: 1.0000e-05
# Epoch 85/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8752 - loss: 0.2451 - val_accuracy: 0.8538 - val_loss: 0.4112 - learning_rate: 1.0000e-05
# Epoch 86/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8764 - loss: 0.2451 - val_accuracy: 0.8482 - val_loss: 0.4257 - learning_rate: 1.0000e-05
# Epoch 87/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8742 - loss: 0.2380 - val_accuracy: 0.8617 - val_loss: 0.4110 - learning_rate: 1.0000e-05
# Epoch 88/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8797 - loss: 0.2473 - val_accuracy: 0.8451 - val_loss: 0.4350 - learning_rate: 1.0000e-05
# Epoch 89/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8762 - loss: 0.2414 - val_accuracy: 0.8474 - val_loss: 0.4306 - learning_rate: 1.0000e-05
# Epoch 90/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8712 - loss: 0.2421 - val_accuracy: 0.8514 - val_loss: 0.4313 - learning_rate: 1.0000e-05
# Epoch 91/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8699 - loss: 0.2534 - val_accuracy: 0.8522 - val_loss: 0.4133 - learning_rate: 1.0000e-05
# Epoch 92/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8742 - loss: 0.2383 - val_accuracy: 0.8609 - val_loss: 0.3947 - learning_rate: 1.0000e-05
# Epoch 93/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8817 - loss: 0.2242 - val_accuracy: 0.8553 - val_loss: 0.4057 - learning_rate: 1.0000e-05
# Epoch 94/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8805 - loss: 0.2274 - val_accuracy: 0.8324 - val_loss: 0.4576 - learning_rate: 1.0000e-05
# Epoch 95/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8833 - loss: 0.2360 - val_accuracy: 0.8609 - val_loss: 0.4130 - learning_rate: 1.0000e-05
# Epoch 96/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8784 - loss: 0.2420 - val_accuracy: 0.8498 - val_loss: 0.4221 - learning_rate: 1.0000e-05
# Epoch 97/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8795 - loss: 0.2362 - val_accuracy: 0.8466 - val_loss: 0.4359 - learning_rate: 1.0000e-05
# Epoch 98/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8774 - loss: 0.2293 - val_accuracy: 0.8482 - val_loss: 0.4409 - learning_rate: 1.0000e-05
# Epoch 99/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8857 - loss: 0.2330 - val_accuracy: 0.8577 - val_loss: 0.4061 - learning_rate: 1.0000e-05
# Epoch 100/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8809 - loss: 0.2248 - val_accuracy: 0.8561 - val_loss: 0.3979 - learning_rate: 1.0000e-05
# Epoch 101/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.8863 - loss: 0.2269 - val_accuracy: 0.8648 - val_loss: 0.3921 - learning_rate: 1.0000e-05
# Epoch 102/200
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8774 - loss: 0.2213 - val_accuracy: 0.8577 - val_loss: 0.4276 - learning_rate: 1.0000e-05
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8264 - loss: 0.5793
# Test loss: 0.5793079137802124
# Test accuracy: 0.8263757228851318

# %%
# Predict and evaluate
y_pred_probs = mSpec_model.predict(X_test_img)

y_pred_cnn = np.argmax(y_pred_probs, axis=1)
y_test_int = np.argmax(y_test_cat, axis=1)

print(classification_report(y_test_int, y_pred_cnn, zero_division=0))
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#               precision    recall  f1-score   support
#
#            0       0.36      0.58      0.44        57
#            1       0.97      0.89      0.93       891
#            2       0.29      0.21      0.24        43
#            3       0.54      0.29      0.38        24
#            4       0.29      1.00      0.45        26
#            5       0.17      0.15      0.16        13
#
#     accuracy                           0.83      1054
#    macro avg       0.44      0.52      0.43      1054
# weighted avg       0.88      0.83      0.84      1054

# %%
# Plot training vs validation curves

history_dict = history.history

# Loss plot
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history_dict["loss"], label="Train Loss")
plt.plot(history_dict["val_loss"], label="Val Loss")
plt.title("Loss Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# Accuracy plot
plt.subplot(1,2,2)
plt.plot(history_dict["accuracy"], label="Train Accuracy")
plt.plot(history_dict["val_accuracy"], label="Val Accuracy")
plt.title("Accuracy Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.tight_layout()
plt.show()
